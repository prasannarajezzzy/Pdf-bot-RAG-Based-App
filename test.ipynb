# %%
import os

import PyPDF2
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain.embeddings import SentenceTransformerEmbeddings

# Define vector_db as a global variable
vector_db = None

# List of available embedding models
embedding_models = [
    "all-MiniLM-L6-v2",
    "paraphrase-MiniLM-L6-v2",
    "msmarco-distilbert-base-tas-b",
    "paraphrase-xlm-r-multilingual-v1",
    "multi-qa-mpnet-base-dot-v1",
    "stsb-roberta-base-v2",
    "nli-roberta-base-v2",
    "nli-mpnet-base-v2",
]


filepath = "./uploads/Receipt_Notice.pdf"

text = ""
with open(filepath, "rb") as file:
    reader = PyPDF2.PdfReader(file)
    for page in reader.pages:
        text += page.extract_text()
if filepath:
    loader = UnstructuredPDFLoader(file_path=filepath)
    data = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=7500, chunk_overlap=100
    )
    chunks = text_splitter.split_documents(data)

    embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
    vector_db = None

    vector_db = Chroma.from_documents(
        documents=chunks,
        embedding=embeddings,
        collection_name="rag-collection",
    )

    print("-------------done-------------")
# Out:
# -------------done-------------

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: aiohttp==3.9.5 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 1)) (3.9.5)
# Requirement already satisfied: aiosignal==1.3.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: annotated-types==0.7.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 4)) (4.9.3)
# Requirement already satisfied: anyio==4.4.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: asgiref==3.8.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: attrs==23.2.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 7)) (23.2.0)
# Requirement already satisfied: backoff==2.2.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: bcrypt==4.1.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 9)) (4.1.3)
# Requirement already satisfied: beautifulsoup4==4.12.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 10)) (4.12.3)
# Collecting blinker==1.8.2 (from -r requirements.txt (line 11))
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: build==1.2.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 12)) (1.2.1)
# Requirement already satisfied: cachetools==5.3.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 13)) (5.3.3)
# Requirement already satisfied: certifi==2024.6.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 14)) (2024.6.2)
# Requirement already satisfied: cffi==1.16.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: chardet==5.2.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 16)) (5.2.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 17)) (3.3.2)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 18)) (0.7.3)
# Requirement already satisfied: chromadb==0.5.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 19)) (0.5.3)
# Requirement already satisfied: click==8.1.7 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 20)) (8.1.7)
# Requirement already satisfied: colorama==0.4.6 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 21)) (0.4.6)
# Requirement already satisfied: coloredlogs==15.0.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 22)) (15.0.1)
# Requirement already satisfied: contourpy==1.2.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 23)) (1.2.1)
# Requirement already satisfied: cryptography==42.0.8 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 24)) (42.0.8)
# Requirement already satisfied: cycler==0.12.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 25)) (0.12.1)
# Requirement already satisfied: dataclasses-json==0.6.7 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 26)) (0.6.7)
# Requirement already satisfied: deepdiff==7.0.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 27)) (7.0.1)
# Requirement already satisfied: Deprecated==1.2.14 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 28)) (1.2.14)
# Requirement already satisfied: dnspython==2.6.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 29)) (2.6.1)
# Requirement already satisfied: effdet==0.4.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 30)) (0.4.1)
# Requirement already satisfied: email_validator==2.2.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 31)) (2.2.0)
# Requirement already satisfied: emoji==2.12.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 32)) (2.12.1)
# Requirement already satisfied: et-xmlfile==1.1.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 33)) (1.1.0)
# Requirement already satisfied: fastapi==0.111.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 34)) (0.111.0)
# Requirement already satisfied: fastapi-cli==0.0.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 35)) (0.0.4)
# Requirement already satisfied: filelock==3.15.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 36)) (3.15.4)
# Requirement already satisfied: filetype==1.2.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 37)) (1.2.0)
# Collecting Flask==3.0.3 (from -r requirements.txt (line 38))
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: flatbuffers==24.3.25 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 39)) (24.3.25)
# Requirement already satisfied: fonttools==4.53.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 40)) (4.53.0)
# Requirement already satisfied: frozenlist==1.4.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 41)) (1.4.1)
# Requirement already satisfied: fsspec==2024.6.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 42)) (2024.6.1)
# Requirement already satisfied: google-api-core==2.19.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 43)) (2.19.1)
# Requirement already satisfied: google-auth==2.30.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 44)) (2.30.0)
# Requirement already satisfied: google-cloud-vision==3.7.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 45)) (3.7.2)
# Requirement already satisfied: googleapis-common-protos==1.63.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 46)) (1.63.2)
# Requirement already satisfied: greenlet==3.0.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 47)) (3.0.3)
# Requirement already satisfied: grpcio==1.64.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 48)) (1.64.1)
# Requirement already satisfied: grpcio-status==1.62.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 49)) (1.62.2)
# Requirement already satisfied: h11==0.14.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 50)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.5 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 51)) (1.0.5)
# Requirement already satisfied: httptools==0.6.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 52)) (0.6.1)
# Requirement already satisfied: httpx==0.27.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 53)) (0.27.0)
# Requirement already satisfied: huggingface-hub==0.23.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 54)) (0.23.4)
# Requirement already satisfied: humanfriendly==10.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 55)) (10.0)
# Requirement already satisfied: idna==3.7 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 56)) (3.7)
# Requirement already satisfied: importlib_metadata==7.1.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 57)) (7.1.0)
# Requirement already satisfied: importlib_resources==6.4.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 58)) (6.4.0)
# Requirement already satisfied: intel-openmp==2021.4.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 59)) (2021.4.0)
# Requirement already satisfied: iopath==0.1.10 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 60)) (0.1.10)
# Collecting itsdangerous==2.2.0 (from -r requirements.txt (line 61))
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: Jinja2==3.1.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 62)) (3.1.4)
# Requirement already satisfied: joblib==1.4.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 63)) (1.4.2)
# Requirement already satisfied: jsonpatch==1.33 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 64)) (1.33)
# Requirement already satisfied: jsonpath-python==1.0.6 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 65)) (1.0.6)
# Requirement already satisfied: jsonpointer==3.0.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 66)) (3.0.0)
# Requirement already satisfied: kiwisolver==1.4.5 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 67)) (1.4.5)
# Requirement already satisfied: kubernetes==30.1.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 68)) (30.1.0)
# Requirement already satisfied: langchain==0.2.6 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 69)) (0.2.6)
# Requirement already satisfied: langchain-community==0.2.6 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 70)) (0.2.6)
# Requirement already satisfied: langchain-core==0.2.10 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 71)) (0.2.10)
# Requirement already satisfied: langchain-text-splitters==0.2.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 72)) (0.2.2)
# Requirement already satisfied: langdetect==1.0.9 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 73)) (1.0.9)
# Requirement already satisfied: langsmith==0.1.82 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 74)) (0.1.82)
# Requirement already satisfied: layoutparser==0.3.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 75)) (0.3.4)
# Requirement already satisfied: lxml==5.2.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 76)) (5.2.2)
# Requirement already satisfied: Markdown==3.6 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 77)) (3.6)
# Requirement already satisfied: markdown-it-py==3.0.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 78)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 79)) (2.1.5)
# Requirement already satisfied: marshmallow==3.21.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 80)) (3.21.3)
# Requirement already satisfied: matplotlib==3.9.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 81)) (3.9.0)
# Requirement already satisfied: mdurl==0.1.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 82)) (0.1.2)
# Requirement already satisfied: mkl==2021.4.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 83)) (2021.4.0)
# Requirement already satisfied: mmh3==4.1.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 84)) (4.1.0)
# Requirement already satisfied: monotonic==1.6 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 85)) (1.6)
# Requirement already satisfied: mpmath==1.3.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 86)) (1.3.0)
# Requirement already satisfied: multidict==6.0.5 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 87)) (6.0.5)
# Requirement already satisfied: mypy-extensions==1.0.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 88)) (1.0.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 89)) (1.6.0)
# Requirement already satisfied: networkx==3.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 90)) (3.3)
# Requirement already satisfied: nltk==3.8.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 91)) (3.8.1)
# Requirement already satisfied: numpy==1.26.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 92)) (1.26.4)
# Requirement already satisfied: oauthlib==3.2.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 93)) (3.2.2)
# Requirement already satisfied: olefile==0.47 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 94)) (0.47)
# Requirement already satisfied: omegaconf==2.3.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 95)) (2.3.0)
# Requirement already satisfied: onnx==1.16.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 96)) (1.16.1)
# Requirement already satisfied: onnxruntime==1.18.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 97)) (1.18.1)
# Requirement already satisfied: opencv-python==4.10.0.84 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 98)) (4.10.0.84)
# Requirement already satisfied: openpyxl==3.1.5 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 99)) (3.1.5)
# Requirement already satisfied: opentelemetry-api==1.25.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 100)) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 101)) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.25.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 102)) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 103)) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 104)) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi==0.46b0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 105)) (0.46b0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 106)) (1.25.0)
# Requirement already satisfied: opentelemetry-sdk==1.25.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 107)) (1.25.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 108)) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 109)) (0.46b0)
# Requirement already satisfied: ordered-set==4.1.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 110)) (4.1.0)
# Requirement already satisfied: orjson==3.10.5 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 111)) (3.10.5)
# Requirement already satisfied: overrides==7.7.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 112)) (7.7.0)
# Requirement already satisfied: packaging==24.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 113)) (24.1)
# Requirement already satisfied: pandas==2.2.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 114)) (2.2.2)
# Requirement already satisfied: pdf2image==1.17.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 115)) (1.17.0)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 116)) (20231228)
# Requirement already satisfied: pdfplumber==0.11.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 117)) (0.11.1)
# Requirement already satisfied: pikepdf==9.0.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 118)) (9.0.0)
# Requirement already satisfied: pillow==10.3.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 119)) (10.3.0)
# Requirement already satisfied: pillow_heif==0.16.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 120)) (0.16.0)
# Requirement already satisfied: portalocker==2.10.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 121)) (2.10.0)
# Requirement already satisfied: posthog==3.5.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 122)) (3.5.0)
# Requirement already satisfied: proto-plus==1.24.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 123)) (1.24.0)
# Requirement already satisfied: protobuf==4.25.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 124)) (4.25.3)
# Requirement already satisfied: psutil==6.0.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 125)) (6.0.0)
# Requirement already satisfied: pyasn1==0.6.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 126)) (0.6.0)
# Requirement already satisfied: pyasn1_modules==0.4.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 127)) (0.4.0)
# Requirement already satisfied: pycocotools==2.0.8 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 128)) (2.0.8)
# Requirement already satisfied: pycparser==2.22 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 129)) (2.22)
# Collecting pydantic==2.7.4 (from -r requirements.txt (line 130))
#   Using cached pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
# Requirement already satisfied: pydantic_core==2.18.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 131)) (2.18.4)
# Requirement already satisfied: Pygments==2.18.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 132)) (2.18.0)
# Requirement already satisfied: pypandoc==1.13 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 133)) (1.13)
# Requirement already satisfied: pyparsing==3.1.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 134)) (3.1.2)
# Requirement already satisfied: pypdf==4.2.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 135)) (4.2.0)
# Collecting PyPDF2==3.0.1 (from -r requirements.txt (line 136))
#   Using cached pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pypdfium2==4.30.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 137)) (4.30.0)
# Requirement already satisfied: PyPika==0.48.9 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 138)) (0.48.9)
# Requirement already satisfied: pyproject_hooks==1.1.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 139)) (1.1.0)
# Requirement already satisfied: pyreadline3==3.4.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 140)) (3.4.1)
# Requirement already satisfied: pytesseract==0.3.10 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 141)) (0.3.10)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 142)) (2.9.0.post0)
# Requirement already satisfied: python-docx==1.1.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 143)) (1.1.2)
# Requirement already satisfied: python-dotenv==1.0.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 144)) (1.0.1)
# Requirement already satisfied: python-iso639==2024.4.27 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 145)) (2024.4.27)
# Requirement already satisfied: python-magic==0.4.27 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 146)) (0.4.27)
# Requirement already satisfied: python-multipart==0.0.9 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 147)) (0.0.9)
# Requirement already satisfied: python-oxmsg==0.0.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 148)) (0.0.1)
# Requirement already satisfied: python-pptx==0.6.23 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 149)) (0.6.23)
# Requirement already satisfied: pytz==2024.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 150)) (2024.1)
# Requirement already satisfied: pywin32==306 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 151)) (306)
# Requirement already satisfied: PyYAML==6.0.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 152)) (6.0.1)
# Requirement already satisfied: rapidfuzz==3.9.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 153)) (3.9.3)
# Requirement already satisfied: regex==2024.5.15 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 154)) (2024.5.15)
# Requirement already satisfied: requests==2.32.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 155)) (2.32.3)
# Requirement already satisfied: requests-oauthlib==2.0.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 156)) (2.0.0)
# Requirement already satisfied: requests-toolbelt==1.0.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 157)) (1.0.0)
# Requirement already satisfied: rich==13.7.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 158)) (13.7.1)
# Requirement already satisfied: rsa==4.9 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 159)) (4.9)
# Requirement already satisfied: safetensors==0.4.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 160)) (0.4.3)
# Requirement already satisfied: scikit-learn==1.5.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 161)) (1.5.0)
# Requirement already satisfied: scipy==1.14.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 162)) (1.14.0)
# Requirement already satisfied: sentence-transformers==3.0.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 163)) (3.0.1)
# Requirement already satisfied: setuptools==70.1.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 164)) (70.1.1)
# Requirement already satisfied: shellingham==1.5.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 165)) (1.5.4)
# Requirement already satisfied: six==1.16.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 166)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 167)) (1.3.1)
# Requirement already satisfied: soupsieve==2.5 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 168)) (2.5)
# Requirement already satisfied: SQLAlchemy==2.0.31 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 169)) (2.0.31)
# Requirement already satisfied: starlette==0.37.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 170)) (0.37.2)
# Requirement already satisfied: sympy==1.12.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 171)) (1.12.1)
# Requirement already satisfied: tabulate==0.9.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 172)) (0.9.0)
# Requirement already satisfied: tbb==2021.13.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 173)) (2021.13.0)
# Requirement already satisfied: tenacity==8.4.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 174)) (8.4.2)
# Requirement already satisfied: threadpoolctl==3.5.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 175)) (3.5.0)
# Requirement already satisfied: timm==1.0.7 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 176)) (1.0.7)
# Collecting tokenizers==0.19.1 (from -r requirements.txt (line 177))
#   Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: torch==2.3.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 178)) (2.3.1)
# Requirement already satisfied: torchvision==0.18.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 179)) (0.18.1)
# Requirement already satisfied: tqdm==4.66.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 180)) (4.66.4)
# Collecting transformers==4.42.3 (from -r requirements.txt (line 181))
#   Using cached transformers-4.42.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: typer==0.12.3 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 182)) (0.12.3)
# Requirement already satisfied: typing-inspect==0.9.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 183)) (0.9.0)
# Requirement already satisfied: typing_extensions==4.12.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 184)) (4.12.2)
# Requirement already satisfied: tzdata==2024.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 185)) (2024.1)
# Requirement already satisfied: ujson==5.10.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 186)) (5.10.0)
# Requirement already satisfied: unstructured==0.14.9 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 187)) (0.14.9)
# Requirement already satisfied: unstructured-client==0.23.8 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 188)) (0.23.8)
# Requirement already satisfied: unstructured-inference==0.7.36 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 189)) (0.7.36)
# Requirement already satisfied: unstructured.pytesseract==0.3.12 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 190)) (0.3.12)
# Requirement already satisfied: urllib3==2.2.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 191)) (2.2.2)
# Requirement already satisfied: uvicorn==0.30.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 192)) (0.30.1)
# Requirement already satisfied: watchfiles==0.22.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 193)) (0.22.0)
# Requirement already satisfied: websocket-client==1.8.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 194)) (1.8.0)
# Requirement already satisfied: websockets==12.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 195)) (12.0)
# Collecting Werkzeug==3.0.3 (from -r requirements.txt (line 196))
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wrapt==1.16.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 197)) (1.16.0)
# Requirement already satisfied: xlrd==2.0.1 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 198)) (2.0.1)
# Requirement already satisfied: XlsxWriter==3.2.0 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 199)) (3.2.0)
# Requirement already satisfied: yarl==1.9.4 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 200)) (1.9.4)
# Requirement already satisfied: zipp==3.19.2 in c:\users\prvaddkkepurakkal\documents\rag\black\myenv\lib\site-packages (from -r requirements.txt (line 201)) (3.19.2)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached pydantic-2.7.4-py3-none-any.whl (409 kB)
# Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl (2.2 MB)
# Using cached transformers-4.42.3-py3-none-any.whl (9.3 MB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Installing collected packages: Werkzeug, PyPDF2, itsdangerous, blinker, pydantic, Flask, tokenizers, transformers
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.17
#     Uninstalling pydantic-1.10.17:
#       Successfully uninstalled pydantic-1.10.17
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# Successfully installed Flask-3.0.3 PyPDF2-3.0.1 Werkzeug-3.0.3 blinker-1.8.2 itsdangerous-2.2.0 pydantic-2.7.4 tokenizers-0.19.1 transformers-4.42.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# farm-haystack 1.26.2 requires pydantic<2, but you have pydantic 2.7.4 which is incompatible.
# farm-haystack 1.26.2 requires transformers==4.39.3, but you have transformers 4.42.3 which is incompatible.

# %%
query_text = "[rasanna]"
print("vecdb", vector_db)
# Query the vector database
if vector_db and query_text:
    results = vector_db.similarity_search(query_text, k=3)
    print(results, "res")

    response = str(results) if results else "No relevant results found."
else:
    response = "Vector database not initialized or query is empty."
# Out:
# vecdb <langchain_community.vectorstores.chroma.Chroma object at 0x0000026E5451D9A0>
# [Document(page_content='Receipt Number IOE9877747501 Received Date 06/15/2024\n\nPriority Date\n\nCase Type I765 - APPLICATION FOR EMPLOYMENT AUTHORIZATION\n\nApplicant VADDKKEPURAKKAL, PRASANNA RAJENDRA\n\nNotice Date 06/15/2024\n\nPage 1 of 2\n\nVADDKKEPURAKKAL, PRASANNA RAJENDRA c/o PRASANNA RAJENDRA VADDKKEPURAKKAL 420 NORD AVE APT 11 CHICO CA 95926-4770\n\nNotice Type: Receipt Notice Amount received: $470.00 U.S. Class requested: C03B\n\nWe have received the application or petition ("your case") listed above. This notice only shows that your case was filed on the "Received Date" listed above. It does NOT grant you any immigration status or immigration benefit, and it is not evidence that your case is still pending. We will notify you in writing when we make a decision on your case or if we need additional information.\n\nPlease save this and any other notices about your case for your records. You should also keep copies of anything you send us, as well as proof of delivery. Have these records available when you contact us about your case.\n\nIf any of the information in your notice is incorrect or you have any questions about your case, you can connect with the USCIS Contact Center at www.uscis.gov/contactcenter or ask about your case online at www.uscis.gov/e-request. You will need your Alien Registration Number (A-Number) and/or the receipt number shown above.\n\nYou can receive updates on your case by visiting www.uscis.gov/casestatus to get the latest status or you can create an account at my.uscis.gov/account and receive email updates for your case.\n\nAutomatic Employment Authorization Document (EAD) Extension - This notice, by itself, does not grant any immigration status or benefit, nor is it evidence that this case is still pending. However, if you are eligible, you may to use this notice in conjunction with your facially expired Form I-766, Employment Authorization Document (EAD), as proof of an automatic extension of employment authorization and/or EAD, as applicable.\n\nYou are eligible for an automatic extension of your employment authorization and/or EAD if:\n\nYou have timely and properly filed to renew your current employment authorization and/or EAD; • Your EAD renewal request is under a category that is eligible for an automatic extension (see uscis.gov/eadautoextend for a list of eligible categories);\n\nThe category on your current EAD matches the "Class Requested" listed on this notice (if you are a Temporary Protected Status (TPS) beneficiary or applicant, your EAD and this notice must contain either the A12 or C19 class, but they do not need to match each other); and\n\nYour EAD renewal application is still pending with USCIS when your current EAD expires.\n\nIf eligible, you may present this notice to an employer with your expired EAD (and Form I-94, Arrival/Departure Record, if applicable) for employment eligibility verification (Form I-9) purposes.\n\nIf eligible, your automatic extension is for up to 540 days from the expiration date printed on the front of your EAD. If we deny your EAD renewal application, the automatic extension immediately ends, and you can no longer present this notice to your employer for Form I-9 purposes. If your EAD is also your Advance Parole document, the automatic extension does not apply to advance parole.\n\nIf you are applying to renew A17, A18, or C26 employment authorization and you are relying upon the automatic extension to demonstrate your employment authorization during the automatic extension period, you must show this receipt notice, an unexpired I-94 showing valid E, L-2, or H-4 status, and a facially expired A17, A18, or C26 EAD that matches this receipt notice. Your EAD automatic extension terminates the earliest of: the end date on your I-94, the date we adjudicate this application, or 540 days after the expiration date on your EAD.\n\nFor more information, please see our website at uscis.gov/eadautoextend.\n\nProcessing time - Processing times vary by  ...

# %%
len(results)
# Out:
# 3

# %%
results[0].to_json()
# Out:
# {'lc': 1,
#  'type': 'constructor',
#  'id': ['langchain', 'schema', 'document', 'Document'],
#  'kwargs': {'page_content': 'Receipt Number IOE9877747501 Received Date 06/15/2024\n\nPriority Date\n\nCase Type I765 - APPLICATION FOR EMPLOYMENT AUTHORIZATION\n\nApplicant VADDKKEPURAKKAL, PRASANNA RAJENDRA\n\nNotice Date 06/15/2024\n\nPage 1 of 2\n\nVADDKKEPURAKKAL, PRASANNA RAJENDRA c/o PRASANNA RAJENDRA VADDKKEPURAKKAL 420 NORD AVE APT 11 CHICO CA 95926-4770\n\nNotice Type: Receipt Notice Amount received: $470.00 U.S. Class requested: C03B\n\nWe have received the application or petition ("your case") listed above. This notice only shows that your case was filed on the "Received Date" listed above. It does NOT grant you any immigration status or immigration benefit, and it is not evidence that your case is still pending. We will notify you in writing when we make a decision on your case or if we need additional information.\n\nPlease save this and any other notices about your case for your records. You should also keep copies of anything you send us, as well as proof of delivery. Have these records available when you contact us about your case.\n\nIf any of the information in your notice is incorrect or you have any questions about your case, you can connect with the USCIS Contact Center at www.uscis.gov/contactcenter or ask about your case online at www.uscis.gov/e-request. You will need your Alien Registration Number (A-Number) and/or the receipt number shown above.\n\nYou can receive updates on your case by visiting www.uscis.gov/casestatus to get the latest status or you can create an account at my.uscis.gov/account and receive email updates for your case.\n\nAutomatic Employment Authorization Document (EAD) Extension - This notice, by itself, does not grant any immigration status or benefit, nor is it evidence that this case is still pending. However, if you are eligible, you may to use this notice in conjunction with your facially expired Form I-766, Employment Authorization Document (EAD), as proof of an automatic extension of employment authorization and/or EAD, as applicable.\n\nYou are eligible for an automatic extension of your employment authorization and/or EAD if:\n\nYou have timely and properly filed to renew your current employment authorization and/or EAD; • Your EAD renewal request is under a category that is eligible for an automatic extension (see uscis.gov/eadautoextend for a list of eligible categories);\n\nThe category on your current EAD matches the "Class Requested" listed on this notice (if you are a Temporary Protected Status (TPS) beneficiary or applicant, your EAD and this notice must contain either the A12 or C19 class, but they do not need to match each other); and\n\nYour EAD renewal application is still pending with USCIS when your current EAD expires.\n\nIf eligible, you may present this notice to an employer with your expired EAD (and Form I-94, Arrival/Departure Record, if applicable) for employment eligibility verification (Form I-9) purposes.\n\nIf eligible, your automatic extension is for up to 540 days from the expiration date printed on the front of your EAD. If we deny your EAD renewal application, the automatic extension immediately ends, and you can no longer present this notice to your employer for Form I-9 purposes. If your EAD is also your Advance Parole document, the automatic extension does not apply to advance parole.\n\nIf you are applying to renew A17, A18, or C26 employment authorization and you are relying upon the automatic extension to demonstrate your employment authorization during the automatic extension period, you must show this receipt notice, an unexpired I-94 showing valid E, L-2, or H-4 status, and a facially expired A17, A18, or C26 EAD that matches this receipt notice. Your EAD automatic extension terminates the earliest of: the end date on your I-94, the date we adjudicate this application, or 540 days after the expiration date on your EAD.\n\nFor more information, please see our website at uscis.gov/eadautoextend.\n\nProcessing time - Processing times var ...
#   'metadata': {'source': './uploads/Receipt_Notice.pdf'},
#   'type': 'Document'}}

# %%
text_res= [i.to_json()["kwargs"]["page_content"] for i in results]
